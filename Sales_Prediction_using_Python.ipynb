# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Advertising=pd.read_csv('/content/Advertising.csv')

# %%
Advertising
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
_df_3['Radio'].plot(kind='hist', bins=20, title='Radio')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_5.plot(kind='scatter', x='Unnamed: 0', y='TV', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_14['TV'].plot(kind='line', figsize=(8, 4), title='TV')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['index']
  ys = series['TV']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_8.sort_values('index', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('index')
_ = plt.ylabel('TV')

# %%
# prompt: Using dataframe Advertising: create grap for TV,Radio,Newspaper product according to their sale

# Import necessary libraries
import altair as alt

# Create a chart using Altair
chart = alt.Chart(Advertising).mark_circle().encode(
    x='TV',
    y='Radio',
    size='Newspaper',
    color='Sales'
).interactive()

# Display the chart
chart
# Out:
# alt.Chart(...)

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Create a bar graph for TV, radio, and newspaper advertising spending
plt.figure(figsize=(10, 6))
plt.bar(['TV', 'Radio', 'Newspaper'], [Advertising['TV'].sum(), Advertising['Radio'].sum(), Advertising['Newspaper'].sum()])
plt.xlabel('Advertising Medium')
plt.ylabel('Total Spending')
plt.title('Total Advertising Spending per Medium')
plt.show()

# Create a scatter plot to show the relationship between sales and advertising spending for each medium
plt.figure(figsize=(12, 6))
plt.scatter(Advertising['TV'], Advertising['Sales'], label='TV')
plt.scatter(Advertising['Radio'], Advertising['Sales'], label='Radio')
plt.scatter(Advertising['Newspaper'], Advertising['Sales'], label='Newspaper')
plt.xlabel('Advertising Spending')
plt.ylabel('Sales')
plt.title('Sales vs. Advertising Spending')
plt.legend()
plt.show()

# %%
Advertising.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
Advertising.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
Advertising.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
Advertising.describe().round(3)
# Out:
#        Unnamed: 0       TV    Radio  Newspaper    Sales
# count     200.000  200.000  200.000    200.000  200.000
# mean      100.500  147.042   23.264     30.554   14.022
# std        57.879   85.854   14.847     21.779    5.217
# min         1.000    0.700    0.000      0.300    1.600
# 25%        50.750   74.375    9.975     12.750   10.375
# 50%       100.500  149.750   22.900     25.750   12.900
# 75%       150.250  218.825   36.525     45.100   17.400
# max       200.000  296.400   49.600    114.000   27.000

# %%
Advertising.isna().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
Advertising.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-89f3fedfbb1d> in <cell line: 1>()
# ----> 1 Advertising.column
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
# Create the heatmap
sns.heatmap(Advertising.corr(),  annot=True, cmap='YlGnBu')

# Customize the plot (optional)
plt.xticks(rotation=15)
plt.title("Sales")

# Display the plot
plt.show()

# %%
# Create a pairplot
sns.pairplot(Advertising)

# Show the plot

plt.show()

# %%
Advertising['Total Advert'] = Advertising['TV'] + Advertising['Radio'] + Advertising['Newspaper']
Advertising
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales  Total Advert
# 0             1  230.1   37.8       69.2   22.1         337.1
# 1             2   44.5   39.3       45.1   10.4         128.9
# 2             3   17.2   45.9       69.3    9.3         132.4
# 3             4  151.5   41.3       58.5   18.5         251.3
# 4             5  180.8   10.8       58.4   12.9         250.0
# ..          ...    ...    ...        ...    ...           ...
# 195         196   38.2    3.7       13.8    7.6          55.7
# 196         197   94.2    4.9        8.1    9.7         107.2
# 197         198  177.0    9.3        6.4   12.8         192.7
# 198         199  283.6   42.0       66.2   25.5         391.8
# 199         200  232.1    8.6        8.7   13.4         249.4
#
# [200 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Unnamed: 0']
  ys = series['Sales']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = Advertising.sort_values('Unnamed: 0', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Unnamed: 0')
_ = plt.ylabel('Sales')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Unnamed: 0']
  ys = series['Newspaper']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = Advertising.sort_values('Unnamed: 0', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Unnamed: 0')
_ = plt.ylabel('Newspaper')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Unnamed: 0']
  ys = series['Radio']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = Advertising.sort_values('Unnamed: 0', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Unnamed: 0')
_ = plt.ylabel('Radio')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Unnamed: 0']
  ys = series['Radio']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = Advertising.sort_values('Unnamed: 0', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Unnamed: 0')
_ = plt.ylabel('Radio')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from math import sqrt
from tabulate import tabulate
# Assigning the features and prediction columns to the X and y columns
X = sales.drop(columns='Sales')
y = sales['Sales']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-5858ceb297a1> in <cell line: 9>()
#       7 from tabulate import tabulate
#       8 # Assigning the features and prediction columns to the X and y columns
# ----> 9 X = sales.drop(columns='Sales')
#      10 y = sales['Sales']
#
# NameError: name 'sales' is not defined
